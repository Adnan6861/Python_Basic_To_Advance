# %% [markdown]
# #  Python Basics to Advance

# %% [markdown]
# ##### python install Setup :  https://www.python.org/downloads/
#
# ##### VS Code Install : https://code.visualstudio.com/

# %% [markdown]
# ## Variable and Data Type

# %% [markdown]
# ### 1. What Are Variables?
#
# Definition:
#
# A variable is a container that temporarily stores data during the execution of a program.
# The value stored in a variable can change during the program's execution, which is why it is called a "variable."
#
# Example:
#
# Imagine a glass of water. The glass is the container, and the water is the data stored in it.
# Similarly, in programming, a variable acts as a container that holds data temporarily.

# %% [markdown]
# ### 2. Rules for Naming Variables
#
#  Key Rules
#
# ##### Start with a Letter or Underscore:
#  Variable names must begin with a letter (a-z, A-Z) or an underscore (_).
#  Example: username, _firstname
#
# ##### Cannot Start with a Number:
#  Variable names cannot begin with a digit.
#
#  ##### Example:
#   1user is invalid, but user1 is valid.
# Use Only Letters, Numbers, and Underscores: Variable names can only contain letters, numbers, and underscores.
#  Example: user_name, age1
#
# ##### Case-Sensitive:
#  Variable names are case-sensitive.
#
#  #### Example:
#   FirstName and firstname are considered two different variables.
#
# ##### Avoid Reserved Words:
#  Do not use Python’s reserved keywords (e.g., print, if, for) as variable names.
#
#  ##### Example:
#   print = 10 is invalid because print is a reserved word.
#
# ##### Meaningful Names:
#  Use meaningful and descriptive names for variables to improve code readability.
#  Example: Use student_name instead of sn.

# %% [markdown]
# ### 3. Variable Naming Conventions
#
# #### Snake Case:
#    All letters are in lowercase, and words are separated by underscores.
#  #### Example:
#    user_name, first_name.
# #### Camel Case:
#     The first word is in lowercase, and the first letter of each subsequent word is capitalized.
#  #### Example:
#   userName, firstName.
# #### Pascal Case:
#  The first letter of each word is capitalized, and there are no separators.
#  Example: UserName, FirstName.

# %% [markdown]
# ### 5. Data Types in Python
#
# ##### Integer
#
# Represents whole numbers (positive or negative) without decimal points.
# Example: 10, -5, 1000.
#
# ##### Float
#
# Represents decimal numbers (positive or negative).
# Example: 3.14, -0.001.
#
# ##### String
#
# Represents a sequence of characters enclosed in single or double quotes.
# Example: 'hello', "python".
# Note: Numbers enclosed in quotes are treated as strings.
# Example: "123" is a string, not an integer.
#
# ##### Boolean
#
# Represents two values: True or False.
# Used in conditions and logical operations.
# Example: is_student = True.
#
#
#
# 6. Practical Examples
#
# Example 1: Assigning Values to Variables
#
#
# country = "Pakistan"  # Assigning a string value
#
#
# age = 25               # Assigning an integer value
#
#
# price = 99.99          # Assigning a float value
#
#
#
# is_active = True       # Assigning a Boolean value
#
#
#
# Example 2: Case-Sensitivity
#
#
# FirstName = "Ali"
#
#
# firstname = "Ahmed"
#
#
#
# Here, FirstName and firstname are two different variables.
#
#
# Example 3: Invalid Variable Names
#
#
# 1user = "Ali"  # Invalid - cannot start with a number
#
#
# print = 10      # Invalid - cannot use reserved words

# %%
number = 1234  #----> int

name= 'Adnan' #------> string

values=0.88 #------> float

values_Boolean= True #----> Boolean Value

# %% [markdown]
# ### Type():
#    is Function Which tell about Data type Of Variable

# %%
name='Adnan'
no=234234
print('Name' , type(name))
print('No',type(no))

float_value=1.5e2
print('Float',type(float_value))
# Out:
# Name <class 'str'>
# No <class 'int'>
# Float <class 'float'>
# sdje  dd fsd ert  gy try rth gh tyy u  dwe ew rer grh yt uy fgbfng kuy  fg b
# <class 'str'>

# %% [markdown]
# 1---use long name of variable --> not Short like x,y,z
# 2---ALso check the values store in int are Not Overflow

# %% [markdown]
# # String :

# %%
story="""sdje  dd fsd ert  gy try rth gh tyy u  dwe ew rer grh yt uy fgbfng kuy  fg b"""
print(story)
print(type(story))

# Specific Operation
#------------------> Concatinate 
f_name='Miraj'
l_name='Muneeb'
concat=f_name +" "+ l_name
print(concat)

#------------------>Repetation--------
rep_value='Muneeb' * 15
print(rep_value)

#=---------------Index and Sclicing -----------------------
slicing_and_index="ABCDEFGHJKLMN"
print('First_index',slicing_and_index[0], 'Last_index',slicing_and_index[-1])

print('slicing',slicing_and_index[0:3],
      slicing_and_index[:2],
     slicing_and_index[2:],
     slicing_and_index[0::8])  #----> also Skip 8 element till end

#---------> f-String ----------------
name='Adnan'
print(f"My Name is  {name}") # is used For Readabilty
# Out:
# sdje  dd fsd ert  gy try rth gh tyy u  dwe ew rer grh yt uy fgbfng kuy  fg b
# <class 'str'>
# Miraj Muneeb
# MuneebMuneebMuneebMuneebMuneebMuneebMuneebMuneebMuneebMuneebMuneebMuneebMuneebMuneebMuneeb
# First_index A Last_index N
# slicing ABC AB CDEFGHJKLMN AJ
# My Name is Adnan Adnan

# %% [markdown]
# # Boolean Type:
#  True False Value used in Condation Check True , False Value  and logical evaluation

# %%
likes_python=True
likes_Dramas=False
print(f"Like Python {type(likes_python)}")   #  used  name is_activate ,isNull , has_error
print(f"Likes_Dramas {type(likes_Dramas)}")
