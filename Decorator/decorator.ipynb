# %%
# def outer_function(same_value):
#     def wraper():
#         print("This is Me")
#         same_value()
#         print('This is You')
#     return wraper

# @outer_function
# def hello():
#     print( 'Bad Boy')
# hello()
# Out:
# This is Me
# Bad Boy
# This is You

# %%
def outer_function(worker_fun):
    def wraper():
        print(f"Name of Call Function:{worker_fun.__name__}")
        worker_fun()
    return wraper
@outer_function
def even_odd():
  print('A.o>A')
  
even_odd()
# Out:
# Name of Call Function:even_odd
# A.o>A
