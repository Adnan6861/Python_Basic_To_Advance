# %%
# object oriented programming

# %%
class student :
    def __init__(self,name,height,age,geneder):
        self.name=name
        self.age=age
        self.geneder=geneder
        self.height=height
    def student_10(self):
        print(f"Name is : {self.name}")
        print(f'Age :{self.age}')
data = student("Adnan", 7.5, 20, "M")
data.student_10()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 10
#       8         print(f"Name is : {self.name}")
#       9         print(f'Age :{self.age}')
# ---> 10 data = student("Adnan", 7.5, 20, "M")
#      11 data.name
#
# Cell In[2], line 5, in student.__init__(self, name, height, age, geneder)
#       3 self.name=name
#       4 self.age=age
# ----> 5 self,geneder=geneder
#       6 self.height=height
#
# ValueError: not enough values to unpack (expected 2, got 1)
